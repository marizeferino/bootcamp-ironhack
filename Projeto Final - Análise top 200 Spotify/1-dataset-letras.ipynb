# %% [markdown]
# # Criando um dataset com as letras das 200 músicas mais tocadas no Spotify
#
# O objetivo desse notebook foi coletar as letras das 200 músicas mais tocadas no Spotify na primeira semana de novembro, para o Brasil, de acordo com a lista gerada pelo [Spotify Charts](https://spotifycharts.com/regional/br/weekly/2019-11-01--2019-11-08)

# %% [markdown]
# # 1. Coletando dados do Genius API usando a biblioteca LyricsGenius
#
#
# ## Sobre a biblioteca LyricsGenius:
#
# De acordo com o documento disponível no [GitHub](https://github.com/johnwmillr/LyricsGenius):
# >"LyricsGenius provides a simple interface to the song, artist, and lyrics data stored on Genius.com."

# %%
# realizando a conexão com a biblioteca

import lyricsgenius

genius = lyricsgenius.Genius(
    "FCPDxhJ92xLxKh5hfCG-HVgweTxgk_OHbx3T-ok3vVn_9jQROwG3sQwMf9T1JO8g") # Client Access Token

# %%
# abrindo o arquivo csv baixado no site do Spotify com as músicas que serão coletadas

top200 = pd.read_csv('top200-nov.csv')
top200.drop(['Position','Streams', 'ID'], axis=1, inplace=True)
top200.head()
# Out:
#                     Track            Artist
# 0                 Surtada      Dadá Boladão
# 1        Gaiola É o Troco       MC Du Black
# 2  Some que ele vem atrás            Anitta
# 3                  Supera  Marília Mendonça
# 4         Hit Contagiante   Felipe Original

# %% [markdown]
# Apliquei um for loop que faz a consulta de acordo com o nome da música e do artista e anexa os resultados à lista 'lyr'. Além disso, implementei uma verificação para quando a letra da música não fosse encontrada (para não causar problemas).

# %%
lyr = []

for i in range(len(top200)):
    track = top200.Track[i]
    artist = top200.Artist[i]
    
    try:
        song = genius.search_song(track, artist) # procura por uma música única de um artista específico
        genius.remove_section_headers = True # remove cabeçalhos da seção(ex. [Refrão]) das letras 
        lyr.append(song.lyrics)
        
    except:
        lyr.append('Não disponível')
# Out:
# Searching for "Surtada" by Dadá Boladão...
# Done.
# Searching for "Gaiola É o Troco" by MC Du Black...
# Done.
# Searching for "Some que ele vem atrás" by Anitta...
# Done.
# Searching for "Supera" by Marília Mendonça...
# Done.
# Searching for "Hit Contagiante" by Felipe Original...
# Done.
# Searching for "Chama Ela" by Lexa...
# Done.
# Searching for "quando a bad bater" by Luan Santana...
# Done.
# Searching for "Cheirosa" by Jorge & Mateus...
# Done.
# Searching for "Contatinho" by Leo Santana...
# Done.
# Searching for "Tijolão" by Jorge & Mateus...
# Done.
# Searching for "Ferida Curada" by Zé Neto & Cristiano...
# Done.
# Searching for "Invocada" by Ludmilla...
# Done.
# Searching for "Lençol Dobrado" by João Gustavo e Murilo...
# Done.
# Searching for "Sentou e Gostou" by MC JottaPê...
# Done.
# Searching for "Quarta Cadeira" by Matheus & Kauan...
# Done.
# Searching for "Quando a vontade bater" by Pk...
# Done.
# Searching for "Kenny G" by Matuê...
# Done.
# Searching for "Complicado" by Vitão...
# Done.
# Searching for "Serenata" by Marília Mendonça...
# Done.
# Searching for "Amor de Que" by Pabllo Vittar...
# Done.
# Searching for "Quem Traiu Levou" by Gusttavo Lima...
# Done.
# Searching for "Parabéns" by Pabllo Vittar...
# Done.
# Searching for "Pupila" by ANAVITÓRIA...
# Done.
# Searching for "Algo Mais" by Xand Avião...
# Done.
# Searching for "Fake News" by Gustavo Mioto...
# Done.
# Searching for "Eterna Sacanagem" by MC JottaPê...
# Done.
# Searching for "Todo Mundo Vai Sofrer" by Marília Mendonça...
# Done.
# Searching for "Espaçosa Demais" by Felipe Araújo...
# No results found for: 'Espaçosa Demais Felipe Araújo'
# Searching for "Bebi Liguei" by Marília Mendonça...
# Done.
# Searching for "Bagunça Minha Vida" by George Henrique & Rodrigo...
# No results found for: 'Bagunça Minha Vida George Henrique & Rodrigo'
# Searching for "Vidrado Em Você" by Dj Guuga...
# Done.
# Searching for "Don't Start Now" by Dua Lipa...
# Done.
# Searching for "Ela Vem" by MC G15...
# Done.
# Searching for "Resenha lá em casa" by MC Kevin o Chris...
# Done.
# Searching for "choque térmico" by Luan Santana...
# Done.
# Searching for "3 Batidas" by Guilherme & Benuto...
# No results found for: '3 Batidas Guilherme & Benuto'
# Searching for "menina solta" by Giulia Be...
# Done.
# Searching for "Cobaia" by Lauana Prado...
# Done.
# Searching for "Para, Pensa e Volta" by Yasmin Santos...
# No results found for: 'Para, Pensa e Volta Yasmin Santos'
# Searching for "Te Amo Sem Compromisso" by MC Doni...
# Done.
# Searching for "Vou Ter Que Superar" by Matheus & Kauan...
# Done.
# Searching for "Baile da Colômbia" by MC Ysa...
# Done.
# Searching for "A Culpa é do Meu Grau" by Diego & Victor Hugo...
# Done.
# Searching for "Tão Linda" by Atitude 67...
# Done.
# Searching for "Gelo" by Melim...
# Done.
# Searching for "Café" by Vitão...
# Done.
# Searching for "Señorita" by Shawn Mendes...
# Done.
# Searching for "Também Sei Fazer Falta" by Israel & Rodolffo...
# No results found for: 'Também Sei Fazer Falta Israel & Rodolffo'
# Searching for "Perrengue" by Gusttavo Lima...
# Done.
# Searching for "Lose You To Love Me" by Selena Gomez...
# Done.
# Searching for "Evoluiu" by MC Kevin o Chris...
# Done.
# Searching for "Relógio Parado" by Diego & Arnaldo...
# No results found for: 'Relógio Parado Diego & Arnaldo'
# Searching for "Lalala" by Y2K...
# Done.
# Searching for "Brisa" by IZA...
# Done.
# Searching for "Carreira Solo" by Gusttavo Lima...
# Done.
# Searching for "Dance Monkey" by Tones and I...
# Done.
# Searching for "Sei Lá" by Projota...
# Done.
# Searching for "Áudio" by Diego & Victor Hugo...
# Done.
# Searching for "Intenção" by Marília Mendonça...
# Done.
# Searching for "Solteiro Não Trai" by Gustavo Mioto...
# Done.
# Searching for "Malemolência" by Dynho Alves...
# Done.
# Searching for "Aí Eu Bebo" by Maiara & Maraisa...
# No results found for: 'Aí Eu Bebo Maiara & Maraisa'
# Searching for "Nem de Graça / Saudade Arregaça" by Pixote...
# No results found for: 'Nem de Graça / Saudade Arregaça Pixote'
# Searching for "Estado Decadente" by Zé Neto & Cristiano...
# Done.
# Searching for "Notificação Preferida" by Zé Neto & Cristiano...
# Done.
# Searching for "Tiro Certo" by Zé Felipe...
# Done.
# Searching for "Pouco a Pouco" by Dilsinho...
# Done.
# Searching for "Bebe e Vem Me Procurar" by Saia Rodada...
# Done.
# Searching for "Para não" by MC WM...
# Done.
# Searching for "Não Abro Mão" by Maiara & Maraisa...
# No results found for: 'Não Abro Mão Maiara & Maraisa'
# Searching for "Maldita de Ex" by Mc Leozin...
# No results found for: 'Maldita de Ex Mc Leozin'
# Searching for "Meu Abrigo" by Melim...
# Done.
# Searching for "Se Prepara 2" by Mc Livinho...
# Done.
# Searching for "Do jeito que tu gosta" by Pk...
# Done.
# Searching for "Onda diferente" by Anitta...
# Done.
# Searching for "Milu" by Gusttavo Lima...
# Done.
# Searching for "Dois Enganados" by Murilo Huff...
# Done.
# Searching for "Mantém" by WIU...
# Done.
# Searching for "In The Dark" by Vintage Culture...
# Done.
# Searching for "Dois Lados" by Wesley Safadão...
# Done.
# Searching for "Na Cama Que Eu Paguei" by Wesley Safadão...
# Done.
# Searching for "Ouvi Dizer" by Melim...
# Done.
# Searching for "Péssimo Negócio" by Dilsinho...
# Done.
# Searching for "Fingindo Maturidade" by Mano Walter...
# Done.
# Searching for "Ela É do Tipo" by MC Kevin o Chris...
# Done.
# Searching for "Flor Que Se Cheira" by Guilherme & Benuto...
# No results found for: 'Flor Que Se Cheira Guilherme & Benuto'
# Searching for "Vai menina" by Pedro Sampaio...
# Done.
# Searching for "Mágica" by Matheus & Kauan...
# Done.
# Searching for "Morena Cor do Pecado" by MC Kevin o Chris...
# Done.
# Searching for "HIGHEST IN THE ROOM" by Travis Scott...
# Done.
# Searching for "Credo que delícia" by MC Kevinho...
# Done.
# Searching for "Apaixonadinha" by Marília Mendonça...
# Done.
# Searching for "Céu Azul" by Pineapple StormTv...
# Done.
# Searching for "Era uma Vez" by Pineapple StormTv...
# Done.
# Searching for "Maturidade" by Avine Vinny...
# Done.
# Searching for "Trip do Boyzinho" by Boyzinho o Rei da Bregadeira...
# Done.
# Searching for "Ciumeira" by Marília Mendonça...
# Done.
# Searching for "Hoje Eu Beberei" by Felipe Araújo...
# No results found for: 'Hoje Eu Beberei Felipe Araújo'
# Searching for "Circles" by Post Malone...
# Done.
# Searching for "I Don't Care" by Ed Sheeran...
# Done.
# Searching for "Meu talismã" by IZA...
# Done.
# Searching for "Acende o Isqueiro" by Orochi...
# Done.
# Searching for "Deixa Tudo Como Tá" by Thiaguinho...
# Done.
# Searching for "Old Town Road" by Lil Nas X...
# Done.
# Searching for "Do Copo Eu Vim" by Diego & Victor Hugo...
# Done.
# Searching for "Deixa" by Lagum...
# Done.
# Searching for "Bomba Relógio" by Luísa Sonza...
# Done.
# Searching for "Someone You Loved" by Lewis Capaldi...
# Done.
# Searching for "Atrasadinha" by Felipe Araújo...
# Done.
# Searching for "Cidade Vizinha" by Henrique & Juliano...
# Done.
# Searching for "Um Pedido" by Hungria Hip Hop...
# Done.
# Searching for "Uma nora pra cada dia" by MC Kevinho...
# Done.
# Searching for "50 Vezes" by Sorriso Maroto...
# No results found for: '50 Vezes Sorriso Maroto'
# Searching for "bad guy" by Billie Eilish...
# Done.
# Searching for "Bebaça" by Marília Mendonça...
# Done.
# Searching for "Piece Of Your Heart" by MEDUZA...
# Done.
# Searching for "Surtada" by DJ Dollynho Da Lapa...
# Done.
# Searching for "Look At Her Now" by Selena Gomez...
# Done.
# Searching for "Saudade em Gotas" by Yasmin Santos...
# No results found for: 'Saudade em Gotas Yasmin Santos'
# Searching for "Fica à vontade" by Pedro Sampaio...
# Done.
# Searching for "Até que enfim" by Ferrugem...
# Done.
# Searching for "Dois Corações" by Melim...
# Done.
# Searching for "Believer" by Imagine Dragons...
# Done.
# Searching for "Apimentadíssima" by Dennis DJ...
# Done.
# Searching for "Sem Sal" by Marília Mendonça...
# Done.
# Searching for "Obrigado por Estragar Tudo" by Marília Mendonça...
# Done.
# Searching for "Não sou obrigada" by POCAH...
# Done.
# Searching for "Dona de mim" by IZA...
# Done.
# Searching for "Flash Pose" by Pabllo Vittar...
# Done.
# Searching for "Namorada Reserva" by Hugo & Guilherme...
# Done.
# Searching for "Casa mais feliz da rua" by João Gustavo e Murilo...
# Done.
# Searching for "Long Neck" by Zé Neto & Cristiano...
# Done.
# Searching for "Pedaço Meu" by Cleber & Cauan...
# No results found for: 'Pedaço Meu Cleber & Cauan'
# Searching for "Embrasa" by Vitão...
# Done.
# Searching for "Bola Rebola" by Tropkillaz...
# Done.
# Searching for "Tchau Tchau" by Henrique & Diego...
# No results found for: 'Tchau Tchau Henrique & Diego'
# Searching for "Positividade" by Mc Bola...
# Done.
# Searching for "Cem Mil" by Gusttavo Lima...
# Done.
# Searching for "Onze e Pouquinho" by Dilsinho...
# No results found for: 'Onze e Pouquinho Dilsinho'
# Searching for "Edredom" by Vitão...
# Done.
# Searching for "Memories" by Maroon 5...
# Done.
# Searching for "Ponte Perra" by Pabllo Vittar...
# Done.
# Searching for "Hoje Eu Vou Parar Na Gaiola" by Mc Livinho...
# Done.
# Searching for "Lights Up" by Harry Styles...
# Done.
# Searching for "S de Saudade" by Luíza & Maurílio...
# Done.
# Searching for "Espelho Meu" by Henrique & Diego...
# Done.
# Searching for "Indomável" by Pk...
# Done.
# Searching for "Oi" by Lagum...
# Done.
# Searching for "7 rings" by Ariana Grande...
# Done.
# Searching for "Piece Of Your Heart" by MEDUZA...
# Done.
# Searching for "Bem Pior Que Eu" by Marília Mendonça...
# Done.
# Searching for "Melhor Saída" by Lauana Prado...
# Done.
# Searching for "Balão" by Orochi...
# Done.
# Searching for "Shallow" by Lady Gaga...
# Done.
# Searching for "Outro Dia" by A Banca Records...
# Done.
# Searching for "It's You" by Ali Gatie...
# Done.
# Searching for "Irmão DQbrada!" by Costa Gold...
# Done.
# Searching for "Teu Segredo" by Vou pro Sereno...
# Done.
# Searching for "Vamos pra Gaiola" by MC Kevin o Chris...
# Done.
# Searching for "Happier" by Marshmello...
# Done.
# Searching for "hot girl bummer" by blackbear...
# Done.
# Searching for "How Do You Sleep?" by Sam Smith...
# Done.
# Searching for "Don’t Call Me Angel" by Ariana Grande...
# Done.
# Searching for "Abandono de Incapaz" by Marília Mendonça...
# Done.
# Searching for "Senta braba" by MC WM...
# Done.
# Searching for "Tonelada de Solidão" by Marcos & Belutti...
# No results found for: 'Tonelada de Solidão Marcos & Belutti'
# Searching for "South of the Border" by Ed Sheeran...
# Done.
# Searching for "Banco" by Matuê...
# Done.
# Searching for "Nem Tchum" by Maiara & Maraisa...
# Done.
# Searching for "Regras" by Diego & Arnaldo...
# No results found for: 'Regras Diego & Arnaldo'
# Searching for "Surtada" by Neo Beats...
# Done.
# Searching for "Largado Às Traças" by Zé Neto & Cristiano...
# Done.
# Searching for "Anos Luz" by Matuê...
# Done.
# Searching for "Pesquisa no Google" by Turma do Pagode...
# Done.
# Searching for "Praia do Rosa" by Oriente...
# Done.
# Searching for "Fica" by ANAVITÓRIA...
# Done.
# Searching for "Infarto" by Diego & Victor Hugo...
# Done.
# Searching for "goosebumps" by Travis Scott...
# Done.
# Searching for "Show De Recaída" by Bruno & Marrone...
# No results found for: 'Show De Recaída Bruno & Marrone'
# Searching for "Nem de Graça" by Pixote...
# Done.
# Searching for "Pra Você Guardei O Amor" by Nando Reis...
# Done.
# Searching for "Conspiração" by Tribo da Periferia...
# Done.
# Searching for "Bye Bye" by Mc Don Juan...
# Done.
# Searching for "Deixa" by Mc Th...
# Done.
# Searching for "Goodbyes" by Post Malone...
# Done.
# Searching for "Bohemian Rhapsody" by Queen...
# Done.
# Searching for "Sua Mãe Vai Me Amar" by Turma do Pagode...
# Done.
# Searching for "Botadona" by Maneiro Na Voz...
# No results found for: 'Botadona Maneiro Na Voz'
# Searching for "Namorar Não Dá" by MC Kevin o Chris...
# Done.
# Searching for "Sunflower" by Post Malone...
# Done.
# Searching for "Liar" by Camila Cabello...
# Done.
# Searching for "Ai, Amor" by ANAVITÓRIA...
# Done.
# Searching for "Garupa 2" by Mc Nando...
# Done.
# Searching for "7 Dias 7 Corpos" by Dj Guuga...
# Done.
# Searching for "Love À Queima Roupa" by Marília Mendonça...
# Done.
# Searching for "Garupa" by Luísa Sonza...
# Done.
# Searching for "Mandona" by Oriente...
# Done.
# Searching for "Dizeres" by Lourena...
# Done.
# Searching for "Cerveja De Garrafa" by Atitude 67...
# Done.
# Searching for "Nave Espacial" by Liu...
# Done.

# %%
# criando um dataframe com as letras extraídas

lyrics = pd.DataFrame(lyr)
lyrics.columns = ['Lyrics']

# %%
# juntando as letras aos nomes da música e do artista

df_lyrics = top200.join(lyrics)

# %%
df_lyrics.head(10)
# Out:
#                     Track            Artist  \
# 0                 Surtada      Dadá Boladão
# 1        Gaiola É o Troco       MC Du Black
# 2  Some que ele vem atrás            Anitta
# 3                  Supera  Marília Mendonça
# 4         Hit Contagiante   Felipe Original
# 5               Chama Ela              Lexa
# 6      quando a bad bater      Luan Santana
# 7                Cheirosa    Jorge & Mateus
# 8              Contatinho       Leo Santana
# 9                 Tijolão    Jorge & Mateus
#
#                                               Lyrics
# 0  [Letra de "Surtada (Remix)" com Dadá Boladão, ...
# 1  Gaiola é o troco\nDu Black na voz, na voz, na ...
# 2  Amiga do céu\nMeu boy me largou\nParou de segu...
# 3  Tá de novo com essa pessoa\nNão  tô acreditand...
# 4  Ahn, fala tu que eu tô cansado\nFelipe Origina...
# 5  1\n• "C Walk", YFG Borges (part. IAMBINHU & YF...
# 6  Amor, eu só quero seu bem\nSe for embora agora...
# 7  1\n• "Meu Drip", Lucas Muto (part. Viper)\n• "...
# 8  1\n• "C Walk", YFG Borges (part. IAMBINHU & YF...
# 9  Eu te conheci depois que a gente largou\nSerá ...

# %% [markdown]
# Olhando o topo do dataframe pode-se observar que algumas letras não foram extraídas corretamente

# %%
# analisando a música Chama Ela, da Lexa, que parece ter sido extraída de forma errada

print(df_lyrics.iloc[5]['Lyrics'])
# Out:
# 1
# • "C Walk", YFG Borges (part. IAMBINHU & YFG Rush)
# 2
# • "Codinome", Maria Andrade
# • "Mano Não Toca Na Lace (Remix)", Azzy (part. Ludmilla & DJ Will 22)
# • "Sentença", Duzz (part. Klyn)
# 3
# • "Curtir a Vida", DJ Dollynho da Lapa (part. MC Cabelinho)
# • "Fah Fah Fah Fah", BC Raff (part. Loc Dog)
# • "Lupa", Sos
# • "Real", DaPaz (part. Azzy, Chris MC & Felp22)
# 4
# • "99", Massaru
# • "Kenny G", Matuê
# • "Senta Como Se Não Houvesse Amanhã", Kevin o Chris (part. MC Calvin & MC Alysson)
# • "Wish", IAMBINHU (part. Ebony & VXNXMS)
# 5
# • "Criminal", ADL (part. Filipe Ret)
# • "Jovem Tralha", Felp22 & Meno Tody
# 6
# • "Contatinho", Léo Santana (part. Anitta)
# • "Malvadão 2", Xamã
# • "Mirando Alto", Burn-O
# • "Nunca Vi", MC Leen (part. ML & Derek)
# • "Overdrive (Remix)", Willsbife
# • "Prada", ZAPI (part. Derek)
# • "Sauce", Lil Preto
# • "Solta a Ousadia", Tainá Costa
# 7
# • "Os Guri da PlanoAlto", Plano Alto (part. França, @pfcarter & AkaLet)
# • "Penny", Massaru
# 8
# • "PLAYBOY BUNNY!!", virgingod (part. Lil Bice)
# 9
# • "Flash", MC Caverinha
# • "Gasolina e Fogo", Menestrel (part. Cynthia Luz & Luccas Carlos)
# • "Só Eu Sei", Devasto Prod (part. Junior Lord, Vandal & Diomedes Chinaski)
# 10
# • "Ria", Kell Smith
# • "Tipo Uma Glock", Jovem Dex
# 11
# • "Lembro de Você", MC Brinquedo
# • "Rave dos Malandros", DJay W (part. Raillow, MC Magal & MC Brisola)
# 12
# • "Hong Kong", Dudu
# • "Rei do Faroeste", F!R3 (part. Vinck & Saik)
# • "Tomio", MC Igu
# 13
# • "A Cobrança", Favela Cria (part. Fast & DK 47)
# • "Brincar de Vida", Dani Russo
# • "carta de amor", OG
# • "Hoje Tem Baile", THE BOY
# • "Perpétua", MC Davi
# • "Sobrevivente", Gabriel, o Pensador
# • "Visão da B", PK Delas (part. MC Rogê)
# • "Wiggle That", Jogvmi (part. Jag)
# 14
# • "Acordei Sorrindo", MC Kabeça
# • "Real Gang", YFG Flacko
# • "Vou de Lacoste", MC IG
# 15
# • "Camisa e Jeans", Lil Xing
# • "Juminai EP 1", MC Igu & Rich V Freak
# • "Me Diz", Horu$
# • "Mexeu Comigo", Charles Santos
# • "Presença VIP", MC Vitinho Avassalador
# • "Sangue Ruim", YFG Daddy
# 16
# • "Ai Droga", Meno Tody (part. MC Cabelinho)
# • "Autoridade", Hot & Oreia (part. MC Caverinha)
# 17
# • "Ela me Olhou", Felp22 (part. FP do Trem Bala)
# • "Pow Pow", MC Rick (part. PK)
# • "Reboladinha", MC Lukkas (part. Kevinho)
# 18
# • "Só Fuga", MC Rhamon (part. MC DR)
# 19
# • "Conspiração", Tribo da Periferia (part. Marília Mendonça)
# • "Hit Cash", BC Raff (part. Glock Di)
# • "Intenção", Thai Flow (part. Luá)
# • "Libre", Emicida (part. Ibeyi)
# 20
# • "Cavalgada", Heavy Baile & Luísa Sonza
# • "Chama Ela", Lexa (part. Pedro Sampaio)
# • "Onde Estará", Delacruz
# • "Sagaz", Maria Andrade
# • "Tá Carente Vem", MC Joãozinho VT
# • "Toma e Depois Desce", Pedro Paulo & Alex (part. MC WM)
# • "Vem Mulher", 3030 (part. MC Rebecca)
# 21
# • "Bota o Gigante pra Cuspir", MC Don Juan
# 22
# • "Rabetão", Gabily (part. Clau & Xamã)
# 23
# • "eu não aguento mais", Lagden
# 24
# • "Maldade", Azzy (part. Boca dos Beats)
# • "não tô bem não", Lagden
# • "Passinho dos Tralhas", MC KF (part. Meno Tody)
# 25
# • "Partiu 2", MC Kekel
# 26
# • "PROIBIDA", BPROBLEMX (part. Sidoka & Chris)
# • "Se Prepara 2", MC Livinho & MC Pedrinho
# 27
# • "Balenciaga", Krawk
# • "Bungee Gum", Antares
# • "Víbora", OG
# 30
# • "Fresh Stars 2020", Pineapple StormTV (part. Sos, Dudu, Meno Tody, Yunk Vino & Ebony)

# %%
# filtrando as músicas com letras extraídas erradas ou não encontradas

mask1 = df_lyrics[df_lyrics['Lyrics'].str.contains('1\n')]
mask2 = df_lyrics[df_lyrics['Lyrics']=='Não disponível']

# %%
print(mask1.index, mask2.index)
# Out:
# Int64Index([5, 7, 8, 25, 33, 44, 68, 75, 79, 100, 102, 123, 130, 144, 181], dtype='int64') Int64Index([ 27,  29,  35,  38,  47,  51,  61,  62,  69,  70,  85,  97, 112,
#             118, 132, 135, 138, 165, 169, 178, 187],
#            dtype='int64')

# %%
# salvando as músicas que ficaram sem a letra correta em um dataframe

df_no_lyrics = pd.DataFrame(df_lyrics.iloc[[5, 7, 8, 25, 33, 44, 68, 75, 79, 100, 102, 123, 130, 144, 181, 27,  29,  
                                            35, 38, 47,  51,  61,  62,  69,  70,  85,  97, 112, 118, 132, 135, 138, 
                                            165, 169, 178, 187]])
df_no_lyrics.head()
# Out:
#                  Track            Artist  \
# 5            Chama Ela              Lexa
# 7             Cheirosa    Jorge & Mateus
# 8           Contatinho       Leo Santana
# 25    Eterna Sacanagem        MC JottaPê
# 33  Resenha lá em casa  MC Kevin o Chris
#
#                                                Lyrics
# 5   1\n• "C Walk", YFG Borges (part. IAMBINHU & YF...
# 7   1\n• "Meu Drip", Lucas Muto (part. Viper)\n• "...
# 8   1\n• "C Walk", YFG Borges (part. IAMBINHU & YF...
# 25  1\n• "Meu Drip", Lucas Muto (part. Viper)\n• "...
# 33  1\n• "BOLT", Febem\n• "Foda-se a Ex", MC Cabel...

# %%
# excluindo coluna Lyrics, pois seus valores não são úteis, já que não foram extraídos corretamente

df_no_lyrics.drop(['Lyrics'], axis=1, inplace=True)

# %%
# excluindo do dataframe as letras que foram extraídas erradas

df_lyrics.drop(index = [5, 7, 8, 25, 33, 44, 68, 75, 79, 100, 102, 123, 130, 144, 181, 27,  29,  35,  38,  47,  51,  
                        61,  62,  69,  70,  85,  97, 112, 118, 132, 135, 138, 165, 169, 178, 187], inplace=True)
df_lyrics.head()
# Out:
#                     Track            Artist  \
# 0                 Surtada      Dadá Boladão
# 1        Gaiola É o Troco       MC Du Black
# 2  Some que ele vem atrás            Anitta
# 3                  Supera  Marília Mendonça
# 4         Hit Contagiante   Felipe Original
#
#                                               Lyrics
# 0  [Letra de "Surtada (Remix)" com Dadá Boladão, ...
# 1  Gaiola é o troco\nDu Black na voz, na voz, na ...
# 2  Amiga do céu\nMeu boy me largou\nParou de segu...
# 3  Tá de novo com essa pessoa\nNão  tô acreditand...
# 4  Ahn, fala tu que eu tô cansado\nFelipe Origina...

# %%
print('A primeira etapa teve como resultado %d letras coletadas corretamente e %d letras que ainda precisam ser coletadas' % (len(df_lyrics), len(df_no_lyrics)))
# Out:
# A primeira etapa teve como resultado 164 letras coletadas corretamente e 36 letras que ainda precisam ser coletadas

# %% [markdown]
# # 2. Web Scraping para coletar as letras que faltaram
#
# Usando a biblioteca Beautiful Soup no site [Letras.mus.br](https://www.letras.mus.br/).

# %%
# importando bibliotecas

import requests
from bs4 import BeautifulSoup

# %%
# função para automatizar o web scraping

def scraper_music(artist_r, track_r):
    
    try:
        url = 'https://www.letras.mus.br/' + str(artist_r).lower().replace(' ', '-').replace('&', '') + '/' + str(track_r).lower().replace(' ', '-') + '/'
        data = requests.get(url)
        soup = BeautifulSoup(data.content, 'html.parser')
    
        lyr_r = soup.find_all('div', {'class' : 'cnt-letra p402_premium'})
        
        lyrics = []

        for item in lyr_r[0].find_all('p'):
            item = str(item)
            item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
            lyrics.append(item)
            
        df_lyrics_r = pd.DataFrame({'Track': track_r, 'Artist': artist_r, 'Lyrics': '\n'.join(lyrics)}, index=[0])
        return df_lyrics_r
        
    except:
        return pd.DataFrame({'Track': track_r, 'Artist': artist_r, 'Lyrics': 'Não disponível'}, index=[0])

# %%
# interando todos os artistas e músicas pela função de web scraping com um for loop

df_no_lyrics = df_no_lyrics.reset_index(drop=True)
df_scrap = pd.DataFrame(columns = ['Track', 'Artist', 'Lyrics'])

for i in range(len(df_no_lyrics)):
    track_rem = df_no_lyrics.Track[i]
    artist_rem = df_no_lyrics.Artist[i]
    df_scrap = df_scrap.append(scraper_music(artist_rem, track_rem))

# %%
# filtrando quais músicas continuam sem a letra

df_scrap = df_scrap.reset_index(drop=True)
df_naodisp = df_scrap[df_scrap['Lyrics']=='Não disponível']
df_naodisp.index
# Out:
# Int64Index([13, 17, 19, 20, 22, 25, 33, 34], dtype='int64')

# %%
# exlcuíndo do df_scrap as músicas que continuam sem a letra

df_scrap.drop(index = [13, 17, 19, 20, 22, 25, 33, 34], inplace=True)

# %% [markdown]
# # 3. Extração manual das letras que estão com padrões de URL diferentes
#
# Ainda usando a biblioteca Beautiful Soup no site [Letras.mus.br](https://www.letras.mus.br/).

# %%
df_naodisp
# Out:
#                               Track              Artist          Lyrics
# 13                     S de Saudade    Luíza & Maurílio  Não disponível
# 17                        3 Batidas  Guilherme & Benuto  Não disponível
# 19           Também Sei Fazer Falta   Israel & Rodolffo  Não disponível
# 20                   Relógio Parado     Diego & Arnaldo  Não disponível
# 22  Nem de Graça / Saudade Arregaça              Pixote  Não disponível
# 25               Flor Que Se Cheira  Guilherme & Benuto  Não disponível
# 33                           Regras     Diego & Arnaldo  Não disponível
# 34                  Show De Recaída     Bruno & Marrone  Não disponível

# %% [markdown]
# - S de Saudade, Luíza & Maurílio

# %%
data1 = requests.get('https://www.letras.mus.br/luiza-e-maurilio/s-de-saudade-part-ze-neto-e-cristiano/')
soup1 = BeautifulSoup(data1.content, 'html.parser')
    
lyr1 = soup1.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics1 = []

for item in lyr1[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics1.append(item)
    
df_lyrics_1 = pd.DataFrame({'Track': 'S de Saudade', 'Artist': 'Luíza & Maurílio', 'Lyrics': '\n'.join(lyrics1)}, index=[0])
    
df_lyrics_1
# Out:
#           Track            Artist  \
# 0  S de Saudade  Luíza & Maurílio
#
#                                               Lyrics
# 0  É, olha eu aqui, na vida de solteiro que eu se...

# %% [markdown]
# - 3 Batidas, Guilherme & Benuto

# %%
data2 = requests.get('https://www.letras.mus.br/guilherme-e-benuto/3-batidas-amando-bebendo-e-sofrendo/')
soup2 = BeautifulSoup(data2.content, 'html.parser')
    
lyr2 = soup2.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics2 = []

for item in lyr2[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics2.append(item)
    
df_lyrics_2 = pd.DataFrame({'Track': '3 Batidas', 'Artist': 'Guilherme & Benuto', 'Lyrics': '\n'.join(lyrics2)}, index=[0])
    
df_lyrics_2
# Out:
#        Track              Artist  \
# 0  3 Batidas  Guilherme & Benuto
#
#                                               Lyrics
# 0  Eu tô rindo, mas é desespero\nTô mais perdido ...

# %% [markdown]
# - Também Sei Fazer Falta, Israel & Rodolffo

# %%
data3 = requests.get('https://www.letras.mus.br/israel-rodolfo/tambem-sei-fazer-falta/')
soup3 = BeautifulSoup(data3.content, 'html.parser')
    
lyr3 = soup3.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics3 = []

for item in lyr3[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics3.append(item)
    
df_lyrics_3 = pd.DataFrame({'Track': 'Também Sei Fazer Falta', 'Artist': 'Israel & Rodolffo', 'Lyrics': '\n'.join(lyrics3)}, index=[0])
    
df_lyrics_3
# Out:
#                     Track             Artist  \
# 0  Também Sei Fazer Falta  Israel & Rodolffo
#
#                                               Lyrics
# 0  Uma pessoa falou que sua pessoa tá pensando em...

# %% [markdown]
# - Relógio Parado, Diego & Arnaldo

# %%
data4 = requests.get('https://www.letras.mus.br/diego-e-arnaldo/relogio-parado/')
soup4 = BeautifulSoup(data4.content, 'html.parser')
    
lyr4 = soup4.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics4 = []

for item in lyr4[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics4.append(item)
    
df_lyrics_4 = pd.DataFrame({'Track': 'Relógio Parado', 'Artist': 'Diego & Arnaldo', 'Lyrics': '\n'.join(lyrics4)}, index=[0])
    
df_lyrics_4
# Out:
#             Track           Artist  \
# 0  Relógio Parado  Diego & Arnaldo
#
#                                               Lyrics
# 0  Ela não sabe ainda\nMas eu vou ser o grande am...

# %% [markdown]
# - Nem de Graça / Saudade Arregaça, Pixote

# %%
data5 = requests.get('https://www.letras.mus.br/pixote/nem-de-graca/')
soup5 = BeautifulSoup(data5.content, 'html.parser')
    
lyr5 = soup5.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics5 = []

for item in lyr5[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics5.append(item)
    
df_lyrics_5 = pd.DataFrame({'Track': 'Nem de Graça / Saudade Arregaça', 'Artist': 'Pixote', 'Lyrics': '\n'.join(lyrics5)}, index=[0])
    
df_lyrics_5
# Out:
#                              Track  Artist  \
# 0  Nem de Graça / Saudade Arregaça  Pixote
#
#                                               Lyrics
# 0  É que não sobrou espaço pra outro alguém\nMinh...

# %% [markdown]
# - Flor Que Se Cheira, Guilherme & Benuto

# %%
data6 = requests.get('https://www.letras.mus.br/guilherme-e-benuto/flor-que-se-cheira/')
soup6 = BeautifulSoup(data6.content, 'html.parser')
    
lyr6 = soup6.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics6 = []

for item in lyr6[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics6.append(item)
    
df_lyrics_6 = pd.DataFrame({'Track': 'Flor Que Se Cheira', 'Artist': 'Guilherme & Benuto', 'Lyrics': '\n'.join(lyrics6)}, index=[0])
    
df_lyrics_6
# Out:
#                 Track              Artist  \
# 0  Flor Que Se Cheira  Guilherme & Benuto
#
#                                               Lyrics
# 0  Cê sabe que o povo comenta sempre\nQue eu pres...

# %% [markdown]
# - Regras, Diego & Arnaldo

# %%
data7 = requests.get('https://www.letras.mus.br/diego-e-arnaldo/regras/')
soup7 = BeautifulSoup(data7.content, 'html.parser')
    
lyr7 = soup7.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics7 = []

for item in lyr7[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics7.append(item)
    
df_lyrics_7 = pd.DataFrame({'Track': 'Regras', 'Artist': 'Diego & Arnaldo', 'Lyrics': '\n'.join(lyrics7)}, index=[0])
    
df_lyrics_7
# Out:
#     Track           Artist                                             Lyrics
# 0  Regras  Diego & Arnaldo  Tava aqui combinando com o meu coração\nEle tá...

# %% [markdown]
# - Show De Recaída, Bruno & Marrone

# %%
data8 = requests.get('https://www.letras.mus.br/bruno-e-marrone/show-de-recaida/')
soup8 = BeautifulSoup(data8.content, 'html.parser')
    
lyr8 = soup8.find_all('div', {'class' : 'cnt-letra p402_premium'})

lyrics8 = []

for item in lyr8[0].find_all('p'):
    item = str(item)
    item = item.replace('<br>', '\n').replace('<br/>', '\n').replace('</br>', '').replace('</p>', '').replace('<p>', '')
    lyrics8.append(item)
    
df_lyrics_8 = pd.DataFrame({'Track': 'Show De Recaída', 'Artist': 'Bruno & Marrone', 'Lyrics': '\n'.join(lyrics8)}, index=[0])
    
df_lyrics_8
# Out:
#              Track           Artist  \
# 0  Show De Recaída  Bruno & Marrone
#
#                                               Lyrics
# 0  Se arrependimento matasse\nEu já tinha morrido...

# %%
df_scrap_manual = pd.concat([df_lyrics_1, df_lyrics_2, df_lyrics_3, df_lyrics_4, df_lyrics_5, 
                             df_lyrics_6, df_lyrics_7, df_lyrics_8])
df_scrap_manual
# Out:
#                              Track              Artist  \
# 0                     S de Saudade    Luíza & Maurílio
# 0                        3 Batidas  Guilherme & Benuto
# 0           Também Sei Fazer Falta   Israel & Rodolffo
# 0                   Relógio Parado     Diego & Arnaldo
# 0  Nem de Graça / Saudade Arregaça              Pixote
# 0               Flor Que Se Cheira  Guilherme & Benuto
# 0                           Regras     Diego & Arnaldo
# 0                  Show De Recaída     Bruno & Marrone
#
#                                               Lyrics
# 0  É, olha eu aqui, na vida de solteiro que eu se...
# 0  Eu tô rindo, mas é desespero\nTô mais perdido ...
# 0  Uma pessoa falou que sua pessoa tá pensando em...
# 0  Ela não sabe ainda\nMas eu vou ser o grande am...
# 0  É que não sobrou espaço pra outro alguém\nMinh...
# 0  Cê sabe que o povo comenta sempre\nQue eu pres...
# 0  Tava aqui combinando com o meu coração\nEle tá...
# 0  Se arrependimento matasse\nEu já tinha morrido...

# %% [markdown]
# # 4. Juntando e salvando os dataframes das três etapas anteriores

# %%
df_letras = pd.concat([df_lyrics, df_scrap, df_scrap_manual])
df_letras = df_letras.reset_index(drop=True)
df_letras.head()
# Out:
#                     Track            Artist  \
# 0                 Surtada      Dadá Boladão
# 1        Gaiola É o Troco       MC Du Black
# 2  Some que ele vem atrás            Anitta
# 3                  Supera  Marília Mendonça
# 4         Hit Contagiante   Felipe Original
#
#                                               Lyrics
# 0  [Letra de "Surtada (Remix)" com Dadá Boladão, ...
# 1  Gaiola é o troco\nDu Black na voz, na voz, na ...
# 2  Amiga do céu\nMeu boy me largou\nParou de segu...
# 3  Tá de novo com essa pessoa\nNão  tô acreditand...
# 4  Ahn, fala tu que eu tô cansado\nFelipe Origina...

# %%
# conferindo se está com as 200 músicas

len(df_letras)
# Out:
# 200

# %%
# salvando em um arquivo csv

df_letras.to_csv('letras_top200.csv', sep = '|', encoding='utf-8', index_label = False)
